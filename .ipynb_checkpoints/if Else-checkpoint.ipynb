# %% [markdown]
# # working with boolean

# %%
# boolean data type
True
# Out:
# True

# %%
False
# Out:
# False

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
bool(5)
# Out:
# True

# %%
bool(-5)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(" ")
# Out:
# True

# %%
0 or 1
# Out:
# 1

# %%
bool(None)
# Out:
# False

# %%
bool(int(45))
# Out:
# True

# %%
bool(-577)
# Out:
# True

# %%
bool("T")
# Out:
# True

# %%
bool('t')
# Out:
# True

# %%
bool("false")
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
bool('')
# Out:
# False

# %%
bool([])
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool([6])
# Out:
# True

# %%
bool(())
# Out:
# False

# %%
bool((6))
# Out:
# True

# %%
a = "pawan"
bool(a)
# Out:
# True

# %% [markdown]
# # comparison operators

# %%
5 >10
# Out:
# False

# %%
10 > 5
# Out:
# True

# %%
5 > 5
# Out:
# False

# %%
18 == 15
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
5 < 10
# Out:
# True

# %%
10 < 10
# Out:
# False

# %%
10 == 10
# Out:
# True

# %%
5 >= 5
# Out:
# True

# %%
5 >= 15
# Out:
# False

# %%
5 <= 15
# Out:
# True

# %%
age = 17

# %%
age >= 18
# Out:
# False

# %%
age = 15

# %%
age <= 18
# Out:
# True

# %%
age != 19
# Out:
# True

# %%
age = 19

# %%
age != 18
# Out:
# True

# %% [markdown]
# # IF elif else

# %%
age = 20
if age > 18:
    print("welcome")
# Out:
# welcome

# %%
age = 5
if age > 18:
    print("welcome")

# %%
age = 14
if age > 18:
    print("welcome")
else:
    print("bye bye")
# Out:
# bye bye

# %%
age > 18
# Out:
# True

# %%
if True:
    print('welcome')
# Out:
# welcome

# %%
marks = 35

# %%
if marks >= 90:
    print("A")
elif marks >= 75:
    print("B")
elif marks >= 60:
    print("C")
elif marks >= 40:
    print("D")
else:
    print("Fail")
# Out:
# Fail

# %%
if True:
    print('hello')
else:
    print("bye")
# Out:
# hello

# %%
if False:
    print('hello')
else:
    print("bye")
# Out:
# bye

# %%
if True:
    print('hello')
elif False:
    print('hi')
else:
    print("bye")
# Out:
# hello
