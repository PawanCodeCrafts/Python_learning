# %% [markdown]
# ## while loop practice

# %%
## dictionary using while loop
d ={
    'name' : 'pawan',
    'age' : 24,
    'education' : 'btech'
}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'education'])

# %%
i = 0
n = len(d)
k = list(d.keys())
while i < n:
    # key = k[i]
    # print(d[key])
    print(d[k[i]])
    i += 1
# Out:
# pawan
# 24
# btech

# %%
l = [1,4,5,6,3,9,0,7]

# %%
## maximum
i = 0
n = len(l)
maxi = 0
while i < n:
    if l[i] > l[maxi]:
        maxi = i
    i += 1
print("index :" , a, ",", "maximum is :",l[maxi])
# Out:
# index : 3 , maximum is : 9

# %%
l = [7,8,4,1,2,9,5]

# %%
## total sum
a = 0
i = 0
n = len(l)
while i < n:
    a += l[i]
    print(l[i],a)
    i+= 1
print(a)
# Out:
# 1 1
# 4 5
# 5 10
# 6 16
# 3 19
# 9 28
# 0 28
# 7 35
# 35

# %%
## minimum
l = [7,8,4,1,2,5]
i = 0
n = len(l)
a = 0
while i < n:
    if l[i] < l[a]:
        a = i
    i += 1
print(a, l[a])
# Out:
# 3 1

# %%
l.sort()

# %%
l
# Out:
# [1, 2, 4, 5, 7, 8]

# %%
l[len(l)//2]
# Out:
# 5

# %%
len(l)//2
# Out:
# 3

# %%
## prime or not 
n = 89
prime = True
i = 2

while i < n:
    if n % i == 0:
        prime = False
        break
    i += 1
if prime:
    print(f'{n} is a prime number')
else:
    print(f'{n} is not a prime number')
# Out:
# 89 is a prime number
